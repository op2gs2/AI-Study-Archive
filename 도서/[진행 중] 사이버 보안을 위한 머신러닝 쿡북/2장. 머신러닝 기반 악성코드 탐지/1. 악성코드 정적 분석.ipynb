# %%
'''샘플의 해시값 계산하기'''
import sys
import hashlib

# 해시값을 계산할 파일을 선택
filename = "./datasets/test.exe"

# MD5/SHA-256 인스턴스 로드, Chunk 크기를 지정
BUF_SIZE = 65536
md5 = hashlib.md5()
sha256 = hashlib.sha256()

# 64KB만큼을 읽어 해시값을 계산한다.
with open(filename, 'rb') as f:
    while True:
        data = f.read(BUF_SIZE)
        if not data:
            break
        md5.update(data)
        sha256.update(data)

# 최종 해시값을 16진수로 출력한다.
print("{}의 MD5 해시값: \n{}\n".format(filename, md5.hexdigest()))
print("{}의 SHA-256 해시값: \n{}\n".format(filename, sha256.hexdigest()))
# Out:
# ./datasets/test.exe의 MD5 해시값:
# fb95de2db64beb631e865e2edb7e93e6
#
# ./datasets/test.exe의 SHA-256 해시값:
# a0a21df8603efafa3ee50e318b9fb2790eef1f66a2391b35f754c899e2f1a979

# %% [markdown]
# ## YARA
# - 규칙과 일치하는 샘플을 분류하는데 도움을 주는 도구
# - 코드 예시
# ```YARA
# # condition과 일치하지 않는 샘플 선택
# rule my_rule_name { condition: false }
#
# # condition에 일치하는 샘플 선택
# rule my_rule_name { condition: true }
#
# # 예시) 100KB가 넘는 모든 파일을 선택하기
# rule over_100kb { condition: filesize > 100KB }
#
# # 예시) PDF의 시그니처를 기반으로, PDF 파일인지 판단
# rule is_a_pdf {
#     strings:
#         $pdf_magic = { 25 50 44 46 }
#     condition:
#         $pdf_magic at 0
# }
# ```
#
# - yara 실습
#     1. 아래의 규칙을 텍스트 파일에 복사하고, 텍스트 파일의 이름을 rules.yara로 한다.
#     ```YARA
#     rule is_a_pdf
#     {
#         strings:
#             $pdf_magic = { 25 50 44 46 }
#         condition:
#             $pdf_magic at 0
#     }
#     rule dummy_rule1
#     {
#         condition: false
#     }
#     rule dummy_rule2
#     {
#         condition: true
#     }
#     ```
#
#     2. YARA 규칙을 적용할 파일을 선택하고, 다음과 같이 터미널에서 명령어를 입력한다.
#     ```bash
#     yara rule.yara PythonBrochure
#
#     # 결과
#     is_a_pdf PythonBrochure.pdf
#     dummy_rule2 PythonBrochure.pdf
#     ```

# %%
'''PE 헤더 검사'''
import pefile

# 분석하고자 하는 파일을 불러들인다.
desired_file = "./datasets/test.exe"
pe = pefile.PE(desired_file)

# PE 파일이 임포트 하는 항목을 나열한다.
for entry in pe.DIRECTORY_ENTRY_IMPORT:
    print(entry.dll)
    for imp in entry.imports:
        print(f"\t{hex(imp.address)},{imp.name}")

# PE 파일의 섹션을 나열한다.
for section in pe.sections:
    print(
        section.Name,
        hex(section.VirtualAddress),
        hex(section.Misc_VirtualSize),
        section.SizeOfRawData,
    )

# 구문 분석한 정보의 전체 덤프를 출력한다.
print(pe.dump_info())
# Out:
# b'KERNEL32.dll'
# 	0x1400279f8,b'SetEvent'
# 	0x140027a00,b'GlobalFree'
# 	0x140027a08,b'GetLocaleInfoW'
# 	0x140027a10,b'CreateFileW'
# 	0x140027a18,b'ReadFile'
# 	0x140027a20,b'GetCurrentProcess'
# 	0x140027a28,b'GetCommandLineW'
# 	0x140027a30,b'HeapSetInformation'
# 	0x140027a38,b'LocalFree'
# 	0x140027a40,b'LocalAlloc'
# 	0x140027a48,b'FindFirstFileW'
# 	0x140027a50,b'FindClose'
# 	0x140027a58,b'FoldStringW'
# 	0x140027a60,b'K32GetModuleFileNameExW'
# 	0x140027a68,b'GetModuleFileNameW'
# 	0x140027a70,b'GetUserDefaultUILanguage'
# 	0x140027a78,b'GetLocalTime'
# 	0x140027a80,b'GetDateFormatW'
# 	0x140027a88,b'GetTimeFormatW'
# 	0x140027a90,b'WideCharToMultiByte'
# 	0x140027a98,b'WriteFile'
# 	0x140027aa0,b'GetFileAttributesW'
# 	0x140027aa8,b'LocalLock'
# 	0x140027ab0,b'GetACP'
# 	0x140027ab8,b'CreateEventExW'
# 	0x140027ac0,b'DeleteFileW'
# 	0x140027ac8,b'SetEndOfFile'
# 	0x140027ad0,b'GetFileAttributesExW'
# 	0x140027ad8,b'GetFileInformationByHandle'
# 	0x140027ae0,b'CreateFileMappingW'
# 	0x140027ae8,b'MapViewOfFile'
# 	0x140027af0,b'MultiByteToWideChar'
# 	0x140027af8,b'LocalReAlloc'
# 	0x140027b00,b'UnmapViewOfFile'
# 	0x140027b08,b'GetFullPathNameW'
# 	0x140027b10,b'LocalSize'
# 	0x140027b18,b'GetStartupInfoW'
# 	0x140027b20,b'lstrcmpiW'
# 	0x140027b28,b'FindNLSString'
# 	0x140027b30,b'GlobalLock'
# 	0x140027b38,b'GlobalUnlock'
# 	0x140027b40,b'GlobalAlloc'
# 	0x140027b48,b'SetCurrentDirectoryW'
# 	0x140027b50,b'GetDiskFreeSpaceExW'
# 	0x140027b58,b'CreateDirectoryW'
# 	0x140027b60,b'RegisterApplicationRestart'
# 	0x140027b68,b'GetCurrentDirectoryW'
# 	0x140027b70,b'CreateProcessW'
# 	0x140027b78,b'WaitForSingleObject'
# 	0x140027b80,b'RaiseException'
# 	0x140027b88,b'MulDiv'
# 	0x140027b90,b'IsDebuggerPresent'
# 	0x140027b98,b'DebugBreak'
# 	0x140027ba0,b'GetModuleHandleW'
# 	0x140027ba8,b'GetProcessHeap'
# 	0x140027bb0,b'GetCurrentProcessId'
# 	0x140027bb8,b'DeleteCriticalSection'
# 	0x140027bc0,b'AcquireSRWLockShared'
# 	0x140027bc8,b'CreateMutexExW'
# 	0x140027bd0,b'GetProcAddress'
# 	0x140027bd8,b'HeapAlloc'
# 	0x140027be0,b'CreateThreadpoolTimer'
# 	0x140027be8,b'ReleaseSRWLockShared'
# 	0x140027bf0,b'SetThreadpoolTimer'
# 	0x140027bf8,b'CloseHandle'
# 	0x140027c00,b'OpenSemaphoreW'
# 	0x140027c08,b'WaitForSingleObjectEx'
# 	0x140027c10,b'AcquireSRWLockExclusive'
# 	0x140027c18,b'CloseThreadpoolTimer'
# 	0x140027c20,b'OutputDebugStringW'
# 	0x140027c28,b'ReleaseSRWLockExclusive'
# 	0x140027c30,b'GetLastError'
# 	0x140027c38,b'FormatMessageW'
# 	0x140027c40,b'GetCurrentThreadId'
# 	0x140027c48,b'ReleaseMutex'
# 	0x140027c50,b'WaitForThreadpoolTimerCallbacks'
# 	0x140027c58,b'InitializeCriticalSectionEx'
# 	0x140027c60,b'LeaveCriticalSection'
# 	0x140027c68,b'GetModuleHandleExW'
# 	0x140027c70,b'ReleaseSemaphore'
# 	0x140027c78,b'EnterCriticalSection'
# 	0x140027c80,b'SetLastError'
# 	0x140027c88,b'HeapFree'
# 	0x140027c90,b'GetModuleFileNameA'
# 	0x140027c98,b'CreateSemaphoreExW'
# 	0x140027ca0,b'LocalUnlock'
# 	0x140027ca8,b'ResolveDelayLoadedAPI'
# 	0x140027cb0,b'DelayLoadFailureHook'
# b'GDI32.dll'
# 	0x140027928,b'CreateDCW'
# 	0x140027930,b'StartPage'
# 	0x140027938,b'StartDocW'
# 	0x140027940,b'SetAbortProc'
# 	0x140027948,b'EndDoc'
# 	0x140027950,b'AbortDoc'
# 	0x140027958,b'EndPage'
# 	0x140027960,b'GetTextMetricsW'
# 	0x140027968,b'SetBkMode'
# 	0x140027970,b'LPtoDP'
# 	0x140027978,b'SetWindowExtEx'
# 	0x140027980,b'SetViewportExtEx'
# 	0x140027988,b'SetMapMode'
# 	0x140027990,b'TextOutW'
# 	0x140027998,b'EnumFontsW'
# 	0x1400279a0,b'GetTextFaceW'
# 	0x1400279a8,b'GetDeviceCaps'
# 	0x1400279b0,b'DeleteDC'
# 	0x1400279b8,b'DeleteObject'
# 	0x1400279c0,b'SetBkColor'
# 	0x1400279c8,b'CreateSolidBrush'
# 	0x1400279d0,b'GetTextExtentPoint32W'
# 	0x1400279d8,b'SelectObject'
# 	0x1400279e0,b'CreateCompatibleDC'
# 	0x1400279e8,b'CreateFontIndirectW'
# b'USER32.dll'
# 	0x140027cc0,b'FillRect'
# 	0x140027cc8,b'DrawTextW'
# 	0x140027cd0,b'DrawFocusRect'
# 	0x140027cd8,b'DefWindowProcW'
# 	0x140027ce0,b'TrackMouseEvent'
# 	0x140027ce8,b'InvalidateRect'
# 	0x140027cf0,b'DestroyIcon'
# 	0x140027cf8,b'SetThreadDpiAwarenessContext'
# 	0x140027d00,b'DialogBoxParamW'
# 	0x140027d08,b'LoadIconW'
# 	0x140027d10,b'GetFocus'
# 	0x140027d18,b'MessageBoxW'
# 	0x140027d20,b'ShowWindow'
# 	0x140027d28,b'SetCursor'
# 	0x140027d30,b'SetActiveWindow'
# 	0x140027d38,b'EnableMenuItem'
# 	0x140027d40,b'IsIconic'
# 	0x140027d48,b'SetFocus'
# 	0x140027d50,b'MessageBeep'
# 	0x140027d58,b'GetForegroundWindow'
# 	0x140027d60,b'GetDlgCtrlID'
# 	0x140027d68,b'SetWindowPos'
# 	0x140027d70,b'RedrawWindow'
# 	0x140027d78,b'GetKeyboardLayout'
# 	0x140027d80,b'CharNextW'
# 	0x140027d88,b'SetWinEventHook'
# 	0x140027d90,b'GetMessageW'
# 	0x140027d98,b'TranslateAcceleratorW'
# 	0x140027da0,b'IsDialogMessageW'
# 	0x140027da8,b'TranslateMessage'
# 	0x140027db0,b'DispatchMessageW'
# 	0x140027db8,b'UnhookWinEvent'
# 	0x140027dc0,b'SetWindowTextW'
# 	0x140027dc8,b'GetMenu'
# 	0x140027dd0,b'GetSubMenu'
# 	0x140027dd8,b'OpenClipboard'
# 	0x140027de0,b'IsClipboardFormatAvailable'
# 	0x140027de8,b'CloseClipboard'
# 	0x140027df0,b'CheckMenuItem'
# 	0x140027df8,b'SetDlgItemTextW'
# 	0x140027e00,b'GetDlgItemTextW'
# 	0x140027e08,b'EndDialog'
# 	0x140027e10,b'SendDlgItemMessageW'
# 	0x140027e18,b'SetScrollPos'
# 	0x140027e20,b'UpdateWindow'
# 	0x140027e28,b'GetWindowPlacement'
# 	0x140027e30,b'SetWindowPlacement'
# 	0x140027e38,b'CharUpperW'
# 	0x140027e40,b'GetSystemMenu'
# 	0x140027e48,b'LoadAcceleratorsW'
# 	0x140027e50,b'SetWindowLongW'
# 	0x140027e58,b'MonitorFromWindow'
# 	0x140027e60,b'RegisterWindowMessageW'
# 	0x140027e68,b'LoadCursorW'
# 	0x140027e70,b'LoadImageW'
# 	0x140027e78,b'GetWindowTextLengthW'
# 	0x140027e80,b'GetWindowLongW'
# 	0x140027e88,b'PeekMessageW'
# 	0x140027e90,b'GetWindowTextW'
# 	0x140027e98,b'EnableWindow'
# 	0x140027ea0,b'CreateDialogParamW'
# 	0x140027ea8,b'DrawTextExW'
# 	0x140027eb0,b'GetClientRect'
# 	0x140027eb8,b'DestroyWindow'
# 	0x140027ec0,b'GetDpiForWindow'
# 	0x140027ec8,b'BeginPaint'
# 	0x140027ed0,b'PostQuitMessage'
# 	0x140027ed8,b'CreateWindowExW'
# 	0x140027ee0,b'RegisterClassExW'
# 	0x140027ee8,b'LoadStringW'
# 	0x140027ef0,b'SystemParametersInfoForDpi'
# 	0x140027ef8,b'SendMessageW'
# 	0x140027f00,b'MoveWindow'
# 	0x140027f08,b'GetDC'
# 	0x140027f10,b'ReleaseDC'
# 	0x140027f18,b'EndPaint'
# 	0x140027f20,b'PostMessageW'
# b'api-ms-win-crt-string-l1-1-0.dll'
# 	0x140028208,b'memset'
# 	0x140028210,b'wcscmp'
# 	0x140028218,b'wcsnlen'
# b'api-ms-win-crt-runtime-l1-1-0.dll'
# 	0x1400281e0,b'_initterm'
# 	0x1400281e8,b'_initterm_e'
# 	0x1400281f0,b'_c_exit'
# 	0x1400281f8,b'_register_thread_local_exe_atexit_callback'
# b'api-ms-win-crt-private-l1-1-0.dll'
# 	0x1400280a8,b'_o__beginthreadex'
# 	0x1400280b0,b'_o__callnewh'
# 	0x1400280b8,b'_o__cexit'
# 	0x1400280c0,b'_o__configthreadlocale'
# 	0x1400280c8,b'_o__configure_wide_argv'
# 	0x1400280d0,b'_o__crt_atexit'
# 	0x1400280d8,b'_o__errno'
# 	0x1400280e0,b'_o__exit'
# 	0x1400280e8,b'_o__get_wide_winmain_command_line'
# 	0x1400280f0,b'_o__initialize_onexit_table'
# 	0x1400280f8,b'_o__initialize_wide_environment'
# 	0x140028100,b'_o__invalid_parameter_noinfo'
# 	0x140028108,b'_o__purecall'
# 	0x140028110,b'_o__register_onexit_function'
# 	0x140028118,b'_o__seh_filter_exe'
# 	0x140028120,b'_o__set_app_type'
# 	0x140028128,b'_o__set_fmode'
# 	0x140028130,b'_o__set_new_mode'
# 	0x140028138,b'_o__wcsicmp'
# 	0x140028140,b'_o__wtol'
# 	0x140028148,b'_o_exit'
# 	0x140028150,b'_o_free'
# 	0x140028158,b'_o_iswdigit'
# 	0x140028160,b'_o_malloc'
# 	0x140028168,b'_o_terminate'
# 	0x140028170,b'__CxxFrameHandler3'
# 	0x140028178,b'__current_exception'
# 	0x140028180,b'__current_exception_context'
# 	0x140028188,b'_CxxThrowException'
# 	0x140028190,b'_o___stdio_common_vswprintf'
# 	0x140028198,b'wcschr'
# 	0x1400281a0,b'__C_specific_handler'
# 	0x1400281a8,b'_o___std_exception_destroy'
# 	0x1400281b0,b'_o___std_exception_copy'
# 	0x1400281b8,b'_o___p__commode'
# 	0x1400281c0,b'memcmp'
# 	0x1400281c8,b'memcpy'
# 	0x1400281d0,b'memmove'
# b'api-ms-win-core-com-l1-1-0.dll'
# 	0x140027f30,b'CoTaskMemAlloc'
# 	0x140027f38,b'CoWaitForMultipleHandles'
# 	0x140027f40,b'CoCreateFreeThreadedMarshaler'
# 	0x140027f48,b'CoCreateInstance'
# 	0x140027f50,b'CoInitializeEx'
# 	0x140027f58,b'CoUninitialize'
# 	0x140027f60,b'CoCreateGuid'
# 	0x140027f68,b'CoTaskMemFree'
# 	0x140027f70,b'PropVariantClear'
# b'api-ms-win-core-shlwapi-legacy-l1-1-0.dll'
# 	0x140028010,b'PathIsFileSpecW'
# 	0x140028018,b'PathFindExtensionW'
# 	0x140028020,b'PathFileExistsW'
# b'api-ms-win-core-winrt-string-l1-1-0.dll'
# 	0x140028080,b'WindowsCreateString'
# 	0x140028088,b'WindowsDeleteString'
# 	0x140028090,b'WindowsCreateStringReference'
# 	0x140028098,b'WindowsGetStringRawBuffer'
# b'api-ms-win-core-winrt-l1-1-0.dll'
# 	0x140028070,b'RoGetActivationFactory'
# b'api-ms-win-shcore-obsolete-l1-1-0.dll'
# 	0x140028228,b'SHStrDupW'
# b'api-ms-win-shcore-path-l1-1-0.dll'
# 	0x140028238,None
# b'api-ms-win-shcore-scaling-l1-1-1.dll'
# 	0x140028248,b'GetDpiForMonitor'
# b'api-ms-win-core-rtlsupport-l1-1-0.dll'
# 	0x140027ff0,b'RtlCaptureContext'
# 	0x140027ff8,b'RtlLookupFunctionEntry'
# 	0x140028000,b'RtlVirtualUnwind'
# b'api-ms-win-core-errorhandling-l1-1-0.dll'
# 	0x140027f80,b'UnhandledExceptionFilter'
# 	0x140027f88,b'SetUnhandledExceptionFilter'
# b'api-ms-win-core-processthreads-l1-1-0.dll'
# 	0x140027fb8,b'TerminateProcess'
# b'api-ms-win-core-processthreads-l1-1-1.dll'
# 	0x140027fc8,b'GetProcessMitigationPolicy'
# 	0x140027fd0,b'IsProcessorFeaturePresent'
# b'api-ms-win-core-profile-l1-1-0.dll'
# 	0x140027fe0,b'QueryPerformanceCounter'
# b'api-ms-win-core-sysinfo-l1-1-0.dll'
# 	0x140028040,b'GetSystemTimeAsFileTime'
# b'api-ms-win-core-interlocked-l1-1-0.dll'
# 	0x140027f98,b'InitializeSListHead'
# b'api-ms-win-core-libraryloader-l1-2-0.dll'
# 	0x140027fa8,b'FreeLibrary'
# b'api-ms-win-core-winrt-error-l1-1-0.dll'
# 	0x140028050,b'SetRestrictedErrorInfo'
# b'api-ms-win-core-string-l1-1-0.dll'
# 	0x140028030,b'CompareStringOrdinal'
# b'api-ms-win-core-winrt-error-l1-1-1.dll'
# 	0x140028060,b'RoGetMatchingRestrictedErrorInfo'
# b'COMCTL32.dll'
# 	0x1400278c8,b'ImageList_SetBkColor'
# 	0x1400278d0,b'CreateStatusWindowW'
# 	0x1400278d8,None
# 	0x1400278e0,b'ImageList_Destroy'
# 	0x1400278e8,None
# 	0x1400278f0,b'ImageList_GetIconSize'
# 	0x1400278f8,b'ImageList_Draw'
# 	0x140027900,None
# 	0x140027908,b'ImageList_ReplaceIcon'
# 	0x140027910,None
# 	0x140027918,b'ImageList_Create'
# b'.text\x00\x00\x00' 0x1000 0x25f22 155648
# b'.rdata\x00\x00' 0x27000 0x98a2 40960
# b'.data\x00\x00\x00' 0x31000 0x26a0 4096
# b'.pdata\x00\x00' 0x34000 0x13ec 8192
# b'.didat\x00\x00' 0x36000 0x188 4096
# b'.rsrc\x00\x00\x00' 0x37000 0x1e1d0 126976
# b'.reloc\x00\x00' 0x56000 0x31c 4096
# ----------DOS_HEADER----------
#
# [IMAGE_DOS_HEADER]
# 0x0        0x0   e_magic:                       0x5A4D
# 0x2        0x2   e_cblp:                        0x90
# 0x4        0x4   e_cp:                          0x3
# 0x6        0x6   e_crlc:                        0x0
# 0x8        0x8   e_cparhdr:                     0x4
# 0xA        0xA   e_minalloc:                    0x0
# 0xC        0xC   e_maxalloc:                    0xFFFF
# 0xE        0xE   e_ss:                          0x0
# 0x10       0x10  e_sp:                          0xB8
# 0x12       0x12  e_csum:                        0x0
# 0x14       0x14  e_ip:                          0x0
# 0x16       0x16  e_cs:                          0x0
# 0x18       0x18  e_lfarlc:                      0x40
# 0x1A       0x1A  e_ovno:                        0x0
# 0x1C       0x1C  e_res:
# 0x24       0x24  e_oemid:                       0x0
# 0x26       0x26  e_oeminfo:                     0x0
# 0x28       0x28  e_res2:
# 0x3C       0x3C  e_lfanew:                      0xF0
#
# ----------NT_HEADERS----------
#
# [IMAGE_NT_HEADERS]
# 0xF0       0x0   Signature:                     0x4550
#
# ----------FILE_HEADER----------
#
# [IMAGE_FILE_HEADER]
# 0xF4       0x0   Machine:                       0x8664
# 0xF6       0x2   NumberOfSections:              0x7
# 0xF8       0x4   TimeDateStamp:                 0xF59533D5 [Sun Jul 25 10:54:13 2100 UTC]
# 0xFC       0x8   PointerToSymbolTable:          0x0
# 0x100      0xC   NumberOfSymbols:               0x0
# 0x104      0x10  SizeOfOptionalHeader:          0xF0
# 0x106      0x12  Characteristics:               0x22
# Flags: IMAGE_FILE_EXECUTABLE_IMAGE, IMAGE_FILE_LARGE_ADDRESS_AWARE
#
# ----------OPTIONAL_HEADER----------
#
# [IMAGE_OPTIONAL_HEADER64]
# 0x108      0x0   Magic:                         0x20B
# 0x10A      0x2   MajorLinkerVersion:            0xE
# 0x10B      0x3   MinorLinkerVersion:            0x1C
# 0x10C      0x4   SizeOfCode:                    0x26000
# 0x110      0x8   SizeOfInitializedData:         0x30000
# 0x114      0xC   SizeOfUninitializedData:       0x0
# 0x118      0x10  AddressOfEntryPoint:           0x1B60
# 0x11C      0x14  BaseOfCode:                    0x1000
# 0x120      0x18  ImageBase:                     0x140000000
# 0x128      0x20  SectionAlignment:              0x1000
# 0x12C      0x24  FileAlignment:                 0x1000
# 0x130      0x28  MajorOperatingSystemVersion:   0xA
# 0x132      0x2A  MinorOperatingSystemVersion:   0x0
# 0x134      0x2C  MajorImageVersion:             0xA
# 0x136      0x2E  MinorImageVersion:             0x0
# 0x138      0x30  MajorSubsystemVersion:         0xA
# 0x13A      0x32  MinorSubsystemVersion:         0x0
# 0x13C      0x34  Reserved1:                     0x0
# 0x140      0x38  SizeOfImage:                   0x57000
# 0x144      0x3C  SizeOfHeaders:                 0x1000
# 0x148      0x40  CheckSum:                      0x618DE
# 0x14C      0x44  Subsystem:                     0x2
# 0x14E      0x46  DllCharacteristics:            0xC160
# 0x150      0x48  SizeOfStackReserve:            0x80000
# 0x158      0x50  SizeOfStackCommit:             0x11000
# 0x160      0x58  SizeOfHeapReserve:             0x100000
# 0x168      0x60  SizeOfHeapCommit:              0x1000
# 0x170      0x68  LoaderFlags:                   0x0
# 0x174      0x6C  NumberOfRvaAndSizes:           0x10
# DllCharacteristics: IMAGE_DLLCHARACTERISTICS_DYNAMIC_BASE, IMAGE_DLLCHARACTERISTICS_GUARD_CF, IMAGE_DLLCHARACTERISTICS_HIGH_ENTROPY_VA, IMAGE_DLLCHARACTERISTICS_NX_COMPAT, IMAGE_DLLCHARACTERISTICS_TERMINAL_SERVER_AWARE
#
# ----------PE Sections----------
#
# [IMAGE_SECTION_HEADER]
# 0x1F8      0x0   Name:                          .text
# 0x200      0x8   Misc:                          0x25F22
# 0x200      0x8   Misc_PhysicalAddress:          0x25F22
# 0x200      0x8   Misc_VirtualSize:              0x25F22
# 0x204      0xC   VirtualAddress:                0x1000
# 0x208      0x10  SizeOfRawData:                 0x26000
# 0x20C      0x14  PointerToRawData:              0x1000
# 0x210      0x18  PointerToRelocations:          0x0
# 0x214      0x1C  PointerToLinenumbers:          0x0
# 0x218      0x20  NumberOfRelocations:           0x0
# 0x21A      0x22  NumberOfLinenumbers:           0x0
# 0x21C      0x24  Characteristics:               0x60000020
# Flags: IMAGE_SCN_CNT_CODE, IMAGE_SCN_MEM_EXECUTE, IMAGE_SCN_MEM_READ
# Entropy: 6.360828 (Min=0.0, Max=8.0)
# MD5     hash: 0dc49699926f0b0ce673fee79b751e21
# SHA-1   hash: ee0fcb96364c0d4eeb24a42aa7efc7fcf3bb3bfa
# SHA-256 hash: 963dce687ecf4379d03b084a0ba4da7c87a510c4403e44ba3e05b611e48a8cff
# SHA-512 hash: 1c8ba97173664bb1714ae0115b74b7dd53db6006dfdf9f5c1ef13a1c5511c40aad96b7cf6ad9bf177871f5ca59f6013ad016b47c286d2891b779be5746c5078a
#
# [IMAGE_SECTION_HEADER]
# 0x220      0x0   Name:                          .rdata
# 0x228      0x8   Misc:                          0x98A2
# 0x228      0x8   Misc_PhysicalAddress:          0x98A2
# 0x228      0x8   Misc_VirtualSize:              0x98A2
# 0x22C      0xC   VirtualAddress:                0x27000
# 0x230      0x10  SizeOfRawData:                 0xA000
# 0x234      0x14  PointerToRawData:              0x27000
# 0x238      0x18  PointerToRelocations:          0x0
# 0x23C      0x1C  PointerToLinenumbers:          0x0
# 0x240      0x20  NumberOfRelocations:           0x0
# 0x242      0x22  NumberOfLinenumbers:           0x0
# 0x244      0x24  Characteristics:               0x40000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ
# Entropy: 5.717645 (Min=0.0, Max=8.0)
# MD5     hash: d381da77f7724506066ccbd990dc6c6a
# SHA-1   hash: bc136645be1fc7736bc25f0462a9c150b8042336
# SHA-256 hash: 20076b9893b1425a0668dbd493dcf95ced9a9695863cc927f56ce9346d2fa229
# SHA-512 hash: b5872acb441950b8c014be9d264dc9366dc8b76dc2c92ea3a822d0cae5c8de3ac08d992400d5b219f2c9d1ca1cadc016dab75437a23e2620fc4de75e6e5bc837
#
# [IMAGE_SECTION_HEADER]
# 0x248      0x0   Name:                          .data
# 0x250      0x8   Misc:                          0x26A0
# 0x250      0x8   Misc_PhysicalAddress:          0x26A0
# 0x250      0x8   Misc_VirtualSize:              0x26A0
# 0x254      0xC   VirtualAddress:                0x31000
# 0x258      0x10  SizeOfRawData:                 0x1000
# 0x25C      0x14  PointerToRawData:              0x31000
# 0x260      0x18  PointerToRelocations:          0x0
# 0x264      0x1C  PointerToLinenumbers:          0x0
# 0x268      0x20  NumberOfRelocations:           0x0
# 0x26A      0x22  NumberOfLinenumbers:           0x0
# 0x26C      0x24  Characteristics:               0xC0000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ, IMAGE_SCN_MEM_WRITE
# Entropy: 1.651104 (Min=0.0, Max=8.0)
# MD5     hash: 57bc922e1434cad6aa6ab5aeacb8293c
# SHA-1   hash: 05d91283244e6dc26aa1a5338e3dc81464dc5a6e
# SHA-256 hash: d4f58ef2dedaf38f2092dbaeffc3e20eaf113a56f63e16e71637686e3bbe0086
# SHA-512 hash: 36c9a3259f27f7b87978ee3bff97413cb623ecbfb620f8afb1635c7cf5cc62ac7a7b68f652f8b3ef5dd0e0499cd2aba973b3c35279cfb533c846ae41ec7e385d
#
# [IMAGE_SECTION_HEADER]
# 0x270      0x0   Name:                          .pdata
# 0x278      0x8   Misc:                          0x13EC
# 0x278      0x8   Misc_PhysicalAddress:          0x13EC
# 0x278      0x8   Misc_VirtualSize:              0x13EC
# 0x27C      0xC   VirtualAddress:                0x34000
# 0x280      0x10  SizeOfRawData:                 0x2000
# 0x284      0x14  PointerToRawData:              0x32000
# 0x288      0x18  PointerToRelocations:          0x0
# 0x28C      0x1C  PointerToLinenumbers:          0x0
# 0x290      0x20  NumberOfRelocations:           0x0
# 0x292      0x22  NumberOfLinenumbers:           0x0
# 0x294      0x24  Characteristics:               0x40000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ
# Entropy: 3.588956 (Min=0.0, Max=8.0)
# MD5     hash: ba9bc6385904662cb71130613bea90c3
# SHA-1   hash: aa04035864112c249c914e5da27e867ef1802ce5
# SHA-256 hash: c9ea40442108660bb8e0eb65051643419c3b69c2b9c9e9340f72d342220bcc54
# SHA-512 hash: 73842f246e79c6c17884cb9f2c96868db067616b912a8ec8ca8b03057938e21cd8943d43a237e398c176e8328f4688a46373ebaa5bad0170d7e89f3d73055700
#
# [IMAGE_SECTION_HEADER]
# 0x298      0x0   Name:                          .didat
# 0x2A0      0x8   Misc:                          0x188
# 0x2A0      0x8   Misc_PhysicalAddress:          0x188
# 0x2A0      0x8   Misc_VirtualSize:              0x188
# 0x2A4      0xC   VirtualAddress:                0x36000
# 0x2A8      0x10  SizeOfRawData:                 0x1000
# 0x2AC      0x14  PointerToRawData:              0x34000
# 0x2B0      0x18  PointerToRelocations:          0x0
# 0x2B4      0x1C  PointerToLinenumbers:          0x0
# 0x2B8      0x20  NumberOfRelocations:           0x0
# 0x2BA      0x22  NumberOfLinenumbers:           0x0
# 0x2BC      0x24  Characteristics:               0xC0000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ, IMAGE_SCN_MEM_WRITE
# Entropy: 0.415682 (Min=0.0, Max=8.0)
# MD5     hash: 58ed8d9d487b27f4ee8c548176a108bd
# SHA-1   hash: 3d33edecfca36da49322dacdc9f1ff95270072d0
# SHA-256 hash: d2488cf39945618211ec7603bc368d4664a201ca43b13e9517597fd6ad0ca22a
# SHA-512 hash: c0b72dca5f2084c08a69d030936c00224b4649c3dab4b346f55dd46f4be62114f5d994c8df15feb81f0a59b928c857b5ea825d3fb64e37818e0dee19e9dd88e0
#
# [IMAGE_SECTION_HEADER]
# 0x2C0      0x0   Name:                          .rsrc
# 0x2C8      0x8   Misc:                          0x1E1D0
# 0x2C8      0x8   Misc_PhysicalAddress:          0x1E1D0
# 0x2C8      0x8   Misc_VirtualSize:              0x1E1D0
# 0x2CC      0xC   VirtualAddress:                0x37000
# 0x2D0      0x10  SizeOfRawData:                 0x1F000
# 0x2D4      0x14  PointerToRawData:              0x35000
# 0x2D8      0x18  PointerToRelocations:          0x0
# 0x2DC      0x1C  PointerToLinenumbers:          0x0
# 0x2E0      0x20  NumberOfRelocations:           0x0
# 0x2E2      0x22  NumberOfLinenumbers:           0x0
# 0x2E4      0x24  Characteristics:               0x40000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ
# Entropy: 6.967527 (Min=0.0, Max=8.0)
# MD5     hash: 8a9261caea67131c263cb4b75332a917
# SHA-1   hash: bfdaa3c972ea0406115674ee8cab34e0d7ac9bba
# SHA-256 hash: c6e6a5e46d95bbc9033eefa49851b0776dde1a9b717931391bd275691591da45
# SHA-512 hash: 5cc87af06f8acde25307fc5d576fce44f25269e2e5da80ef8a71859db200334b63cee3510f60d2b0bda18d7689312a93b9f8df3136d33e62a845fdb290b46dad
#
# [IMAGE_SECTION_HEADER]
# 0x2E8      0x0   Name:                          .reloc
# 0x2F0      0x8   Misc:                          0x31C
# 0x2F0      0x8   Misc_PhysicalAddress:          0x31C
# 0x2F0      0x8   Misc_VirtualSize:              0x31C
# 0x2F4      0xC   VirtualAddress:                0x56000
# 0x2F8      0x10  SizeOfRawData:                 0x1000
# 0x2FC      0x14  PointerToRawData:              0x54000
# 0x300      0x18  PointerToRelocations:          0x0
# 0x304      0x1C  PointerToLinenumbers:          0x0
# 0x308      0x20  NumberOfRelocations:           0x0
# 0x30A      0x22  NumberOfLinenumbers:           0x0
# 0x30C      0x24  Characteristics:               0x42000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_DISCARDABLE, IMAGE_SCN_MEM_READ
# Entropy: 1.593970 (Min=0.0, Max=8.0)
# MD5     hash: c18e62682f944179c507c8d057eb64e0
# SHA-1   hash: a60589648d130a6a25410c1ed44377e0639c803d
# SHA-256 hash: 19224e07e9470279d3421042d01360dd6adc7c52d96b0a46c16f1ad631a2901c
# SHA-512 hash: d2c7422a790eb8b7b7e3fee966d9e1dbf586de77760838bd73d5762c42a1a71bd241e573283de7dd750478e0d4d96df148c43026954d33da6e9bdca7a83fa53b
#
# ----------Directories----------
#
# [IMAGE_DIRECTORY_ENTRY_EXPORT]
# 0x178      0x0   VirtualAddress:                0x0
# 0x17C      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_IMPORT]
# 0x180      0x0   VirtualAddress:                0x2E588
# 0x184      0x4   Size:                          0x208
# [IMAGE_DIRECTORY_ENTRY_RESOURCE]
# 0x188      0x0   VirtualAddress:                0x37000
# 0x18C      0x4   Size:                          0x1E1D0
# [IMAGE_DIRECTORY_ENTRY_EXCEPTION]
# 0x190      0x0   VirtualAddress:                0x34000
# 0x194      0x4   Size:                          0x13EC
# [IMAGE_DIRECTORY_ENTRY_SECURITY]
# 0x198      0x0   VirtualAddress:                0x0
# 0x19C      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_BASERELOC]
# 0x1A0      0x0   VirtualAddress:                0x56000
# 0x1A4      0x4   Size:                          0x31C
# [IMAGE_DIRECTORY_ENTRY_DEBUG]
# 0x1A8      0x0   VirtualAddress:                0x2C160
# 0x1AC      0x4   Size:                          0x54
# [IMAGE_DIRECTORY_ENTRY_COPYRIGHT]
# 0x1B0      0x0   VirtualAddress:                0x0
# 0x1B4      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_GLOBALPTR]
# 0x1B8      0x0   VirtualAddress:                0x0
# 0x1BC      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_TLS]
# 0x1C0      0x0   VirtualAddress:                0x0
# 0x1C4      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_LOAD_CONFIG]
# 0x1C8      0x0   VirtualAddress:                0x27790
# 0x1CC      0x4   Size:                          0x138
# [IMAGE_DIRECTORY_ENTRY_BOUND_IMPORT]
# 0x1D0      0x0   VirtualAddress:                0x0
# 0x1D4      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_IAT]
# 0x1D8      0x0   VirtualAddress:                0x278C8
# 0x1DC      0x4   Size:                          0x990
# [IMAGE_DIRECTORY_ENTRY_DELAY_IMPORT]
# 0x1E0      0x0   VirtualAddress:                0x2DE58
# 0x1E4      0x4   Size:                          0xE0
# [IMAGE_DIRECTORY_ENTRY_COM_DESCRIPTOR]
# 0x1E8      0x0   VirtualAddress:                0x0
# 0x1EC      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_RESERVED]
# 0x1F0      0x0   VirtualAddress:                0x0
# 0x1F4      0x4   Size:                          0x0
#
# ----------Version Information----------
#
# [VS_VERSIONINFO]
# 0x52D18    0x0   Length:                        0x364
# 0x52D1A    0x2   ValueLength:                   0x34
# 0x52D1C    0x4   Type:                          0x0
#
# [VS_FIXEDFILEINFO]
# 0x52D40    0x0   Signature:                     0xFEEF04BD
# 0x52D44    0x4   StrucVersion:                  0x10000
# 0x52D48    0x8   FileVersionMS:                 0xA0000
# 0x52D4C    0xC   FileVersionLS:                 0x55F00001
# 0x52D50    0x10  ProductVersionMS:              0xA0000
# 0x52D54    0x14  ProductVersionLS:              0x55F00001
# 0x52D58    0x18  FileFlagsMask:                 0x3F
# 0x52D5C    0x1C  FileFlags:                     0x0
# 0x52D60    0x20  FileOS:                        0x40004
# 0x52D64    0x24  FileType:                      0x1
# 0x52D68    0x28  FileSubtype:                   0x0
# 0x52D6C    0x2C  FileDateMS:                    0x0
# 0x52D70    0x30  FileDateLS:                    0x0
#
# [StringFileInfo]
# 0x52D74    0x0   Length:                        0x2C2
# 0x52D76    0x2   ValueLength:                   0x0
# 0x52D78    0x4   Type:                          0x1
#
#   [StringTable]
#   0x52D98    0x0   Length:                        0x29E
#   0x52D9A    0x2   ValueLength:                   0x0
#   0x52D9C    0x4   Type:                          0x1
#   LangID: 040904B0
#
#     CompanyName: Microsoft Corporation
#     FileDescription: Notepad
#     FileVersion: 10.0.22000.1 (WinBuild.160101.0800)
#     InternalName: Notepad
#     LegalCopyright: \xc2\xa9 Microsoft Corporation. All rights reserved.
#     OriginalFilename: NOTEPAD.EXE
#     ProductName: Microsoft\xc2\xae Windows\xc2\xae Operating System
#     ProductVersion: 10.0.22000.1
#
# [VarFileInfo]
# 0x53038    0x0   Length:                        0x44
# 0x5303A    0x2   ValueLength:                   0x0
# 0x5303C    0x4   Type:                          0x1
#
#   [Var]
#   0x53058    0x0   Length:                        0x24
#   0x5305A    0x2   ValueLength:                   0x4
#   0x5305C    0x4   Type:                          0x0
#     Translation: 0x0409 0x04b0
#
# ----------Imported symbols----------
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E588    0x0   OriginalFirstThunk:            0x2E8C0
# 0x2E588    0x0   Characteristics:               0x2E8C0
# 0x2E58C    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E590    0x8   ForwarderChain:                0x0
# 0x2E594    0xC   Name:                          0x2F786
# 0x2E598    0x10  FirstThunk:                    0x279F8
#
# KERNEL32.dll.SetEvent Hint[1340]
# KERNEL32.dll.GlobalFree Hint[850]
# KERNEL32.dll.GetLocaleInfoW Hint[632]
# KERNEL32.dll.CreateFileW Hint[211]
# KERNEL32.dll.ReadFile Hint[1164]
# KERNEL32.dll.GetCurrentProcess Hint[554]
# KERNEL32.dll.GetCommandLineW Hint[489]
# KERNEL32.dll.HeapSetInformation Hint[875]
# KERNEL32.dll.LocalFree Hint[1000]
# KERNEL32.dll.LocalAlloc Hint[995]
# KERNEL32.dll.FindFirstFileW Hint[402]
# KERNEL32.dll.FindClose Hint[391]
# KERNEL32.dll.FoldStringW Hint[438]
# KERNEL32.dll.K32GetModuleFileNameExW Hint[956]
# KERNEL32.dll.GetModuleFileNameW Hint[648]
# KERNEL32.dll.GetUserDefaultUILanguage Hint[819]
# KERNEL32.dll.GetLocalTime Hint[629]
# KERNEL32.dll.GetDateFormatW Hint[565]
# KERNEL32.dll.GetTimeFormatW Hint[808]
# KERNEL32.dll.WideCharToMultiByte Hint[1577]
# KERNEL32.dll.WriteFile Hint[1597]
# KERNEL32.dll.GetFileAttributesW Hint[601]
# KERNEL32.dll.LocalLock Hint[1002]
# KERNEL32.dll.GetACP Hint[452]
# KERNEL32.dll.CreateEventExW Hint[198]
# KERNEL32.dll.DeleteFileW Hint[288]
# KERNEL32.dll.SetEndOfFile Hint[1334]
# KERNEL32.dll.GetFileAttributesExW Hint[598]
# KERNEL32.dll.GetFileInformationByHandle Hint[603]
# KERNEL32.dll.CreateFileMappingW Hint[208]
# KERNEL32.dll.MapViewOfFile Hint[1015]
# KERNEL32.dll.MultiByteToWideChar Hint[1032]
# KERNEL32.dll.LocalReAlloc Hint[1003]
# KERNEL32.dll.UnmapViewOfFile Hint[1499]
# KERNEL32.dll.GetFullPathNameW Hint[621]
# KERNEL32.dll.LocalSize Hint[1005]
# KERNEL32.dll.GetStartupInfoW Hint[744]
# KERNEL32.dll.lstrcmpiW Hint[1634]
# KERNEL32.dll.FindNLSString Hint[409]
# KERNEL32.dll.GlobalLock Hint[854]
# KERNEL32.dll.GlobalUnlock Hint[861]
# KERNEL32.dll.GlobalAlloc Hint[843]
# KERNEL32.dll.SetCurrentDirectoryW Hint[1327]
# KERNEL32.dll.GetDiskFreeSpaceExW Hint[572]
# KERNEL32.dll.CreateDirectoryW Hint[194]
# KERNEL32.dll.RegisterApplicationRestart Hint[1212]
# KERNEL32.dll.GetCurrentDirectoryW Hint[547]
# KERNEL32.dll.CreateProcessW Hint[238]
# KERNEL32.dll.WaitForSingleObject Hint[1538]
# KERNEL32.dll.RaiseException Hint[1147]
# KERNEL32.dll.MulDiv Hint[1031]
# KERNEL32.dll.IsDebuggerPresent Hint[919]
# KERNEL32.dll.DebugBreak Hint[273]
# KERNEL32.dll.GetModuleHandleW Hint[652]
# KERNEL32.dll.GetProcessHeap Hint[715]
# KERNEL32.dll.GetCurrentProcessId Hint[555]
# KERNEL32.dll.DeleteCriticalSection Hint[283]
# KERNEL32.dll.AcquireSRWLockShared Hint[1]
# KERNEL32.dll.CreateMutexExW Hint[225]
# KERNEL32.dll.GetProcAddress Hint[708]
# KERNEL32.dll.HeapAlloc Hint[867]
# KERNEL32.dll.CreateThreadpoolTimer Hint[255]
# KERNEL32.dll.ReleaseSRWLockShared Hint[1229]
# KERNEL32.dll.SetThreadpoolTimer Hint[1424]
# KERNEL32.dll.CloseHandle Hint[142]
# KERNEL32.dll.OpenSemaphoreW Hint[1064]
# KERNEL32.dll.WaitForSingleObjectEx Hint[1539]
# KERNEL32.dll.AcquireSRWLockExclusive Hint[0]
# KERNEL32.dll.CloseThreadpoolTimer Hint[152]
# KERNEL32.dll.OutputDebugStringW Hint[1072]
# KERNEL32.dll.ReleaseSRWLockExclusive Hint[1228]
# KERNEL32.dll.GetLastError Hint[628]
# KERNEL32.dll.FormatMessageW Hint[441]
# KERNEL32.dll.GetCurrentThreadId Hint[559]
# KERNEL32.dll.ReleaseMutex Hint[1225]
# KERNEL32.dll.WaitForThreadpoolTimerCallbacks Hint[1541]
# KERNEL32.dll.InitializeCriticalSectionEx Hint[894]
# KERNEL32.dll.LeaveCriticalSection Hint[982]
# KERNEL32.dll.GetModuleHandleExW Hint[651]
# KERNEL32.dll.ReleaseSemaphore Hint[1230]
# KERNEL32.dll.EnterCriticalSection Hint[321]
# KERNEL32.dll.SetLastError Hint[1367]
# KERNEL32.dll.HeapFree Hint[871]
# KERNEL32.dll.GetModuleFileNameA Hint[647]
# KERNEL32.dll.CreateSemaphoreExW Hint[244]
# KERNEL32.dll.LocalUnlock Hint[1007]
# KERNEL32.dll.ResolveDelayLoadedAPI Hint[1251]
# KERNEL32.dll.DelayLoadFailureHook Hint[280]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E59C    0x0   OriginalFirstThunk:            0x2E7F0
# 0x2E59C    0x0   Characteristics:               0x2E7F0
# 0x2E5A0    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E5A4    0x8   ForwarderChain:                0x0
# 0x2E5A8    0xC   Name:                          0x2F910
# 0x2E5AC    0x10  FirstThunk:                    0x27928
#
# GDI32.dll.CreateDCW Hint[52]
# GDI32.dll.StartPage Hint[931]
# GDI32.dll.StartDocW Hint[929]
# GDI32.dll.SetAbortProc Hint[874]
# GDI32.dll.EndDoc Hint[402]
# GDI32.dll.AbortDoc Hint[0]
# GDI32.dll.EndPage Hint[405]
# GDI32.dll.GetTextMetricsW Hint[731]
# GDI32.dll.SetBkMode Hint[880]
# GDI32.dll.LPtoDP Hint[747]
# GDI32.dll.SetWindowExtEx Hint[925]
# GDI32.dll.SetViewportExtEx Hint[921]
# GDI32.dll.SetMapMode Hint[901]
# GDI32.dll.TextOutW Hint[938]
# GDI32.dll.EnumFontsW Hint[459]
# GDI32.dll.GetTextFaceW Hint[729]
# GDI32.dll.GetDeviceCaps Hint[639]
# GDI32.dll.DeleteDC Hint[389]
# GDI32.dll.DeleteObject Hint[392]
# GDI32.dll.SetBkColor Hint[879]
# GDI32.dll.CreateSolidBrush Hint[90]
# GDI32.dll.GetTextExtentPoint32W Hint[723]
# GDI32.dll.SelectObject Hint[872]
# GDI32.dll.CreateCompatibleDC Hint[49]
# GDI32.dll.CreateFontIndirectW Hint[67]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E5B0    0x0   OriginalFirstThunk:            0x2EB88
# 0x2E5B0    0x0   Characteristics:               0x2EB88
# 0x2E5B4    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E5B8    0x8   ForwarderChain:                0x0
# 0x2E5BC    0xC   Name:                          0x2FE3A
# 0x2E5C0    0x10  FirstThunk:                    0x27CC0
#
# USER32.dll.FillRect Hint[272]
# USER32.dll.DrawTextW Hint[222]
# USER32.dll.DrawFocusRect Hint[210]
# USER32.dll.DefWindowProcW Hint[167]
# USER32.dll.TrackMouseEvent Hint[939]
# USER32.dll.InvalidateRect Hint[547]
# USER32.dll.DestroyIcon Hint[177]
# USER32.dll.SetThreadDpiAwarenessContext Hint[875]
# USER32.dll.DialogBoxParamW Hint[186]
# USER32.dll.LoadIconW Hint[602]
# USER32.dll.GetFocus Hint[344]
# USER32.dll.MessageBoxW Hint[650]
# USER32.dll.ShowWindow Hint[914]
# USER32.dll.SetCursor Hint[808]
# USER32.dll.SetActiveWindow Hint[795]
# USER32.dll.EnableMenuItem Hint[233]
# USER32.dll.IsIconic Hint[566]
# USER32.dll.SetFocus Hint[823]
# USER32.dll.MessageBeep Hint[642]
# USER32.dll.GetForegroundWindow Hint[345]
# USER32.dll.GetDlgCtrlID Hint[332]
# USER32.dll.SetWindowPos Hint[894]
# USER32.dll.RedrawWindow Hint[730]
# USER32.dll.GetKeyboardLayout Hint[362]
# USER32.dll.CharNextW Hint[52]
# USER32.dll.SetWinEventHook Hint[882]
# USER32.dll.GetMessageW Hint[394]
# USER32.dll.TranslateAcceleratorW Hint[944]
# USER32.dll.IsDialogMessageW Hint[562]
# USER32.dll.TranslateMessage Hint[946]
# USER32.dll.DispatchMessageW Hint[189]
# USER32.dll.UnhookWinEvent Hint[949]
# USER32.dll.SetWindowTextW Hint[899]
# USER32.dll.GetMenu Hint[376]
# USER32.dll.GetSubMenu Hint[451]
# USER32.dll.OpenClipboard Hint[667]
# USER32.dll.IsClipboardFormatAvailable Hint[559]
# USER32.dll.CloseClipboard Hint[79]
# USER32.dll.CheckMenuItem Hint[67]
# USER32.dll.SetDlgItemTextW Hint[820]
# USER32.dll.GetDlgItemTextW Hint[336]
# USER32.dll.EndDialog Hint[242]
# USER32.dll.SendDlgItemMessageW Hint[783]
# USER32.dll.SetScrollPos Hint[863]
# USER32.dll.UpdateWindow Hint[972]
# USER32.dll.GetWindowPlacement Hint[495]
# USER32.dll.SetWindowPlacement Hint[893]
# USER32.dll.CharUpperW Hint[63]
# USER32.dll.GetSystemMenu Hint[455]
# USER32.dll.LoadAcceleratorsW Hint[594]
# USER32.dll.SetWindowLongW Hint[892]
# USER32.dll.MonitorFromWindow Hint[655]
# USER32.dll.RegisterWindowMessageW Hint[762]
# USER32.dll.LoadCursorW Hint[600]
# USER32.dll.LoadImageW Hint[604]
# USER32.dll.GetWindowTextLengthW Hint[503]
# USER32.dll.GetWindowLongW Hint[490]
# USER32.dll.PeekMessageW Hint[681]
# USER32.dll.GetWindowTextW Hint[504]
# USER32.dll.EnableWindow Hint[239]
# USER32.dll.CreateDialogParamW Hint[106]
# USER32.dll.DrawTextExW Hint[221]
# USER32.dll.GetClientRect Hint[307]
# USER32.dll.DestroyWindow Hint[181]
# USER32.dll.GetDpiForWindow Hint[341]
# USER32.dll.BeginPaint Hint[17]
# USER32.dll.PostQuitMessage Hint[686]
# USER32.dll.CreateWindowExW Hint[118]
# USER32.dll.RegisterClassExW Hint[734]
# USER32.dll.LoadStringW Hint[615]
# USER32.dll.SystemParametersInfoForDpi Hint[929]
# USER32.dll.SendMessageW Hint[792]
# USER32.dll.MoveWindow Hint[656]
# USER32.dll.GetDC Hint[322]
# USER32.dll.ReleaseDC Hint[764]
# USER32.dll.EndPaint Hint[244]
# USER32.dll.PostMessageW Hint[685]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E5C4    0x0   OriginalFirstThunk:            0x2F0D0
# 0x2E5C4    0x0   Characteristics:               0x2F0D0
# 0x2E5C8    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E5CC    0x8   ForwarderChain:                0x0
# 0x2E5D0    0xC   Name:                          0x2FEA2
# 0x2E5D4    0x10  FirstThunk:                    0x28208
#
# api-ms-win-crt-string-l1-1-0.dll.memset Hint[131]
# api-ms-win-crt-string-l1-1-0.dll.wcscmp Hint[158]
# api-ms-win-crt-string-l1-1-0.dll.wcsnlen Hint[169]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E5D8    0x0   OriginalFirstThunk:            0x2F0A8
# 0x2E5D8    0x0   Characteristics:               0x2F0A8
# 0x2E5DC    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E5E0    0x8   ForwarderChain:                0x0
# 0x2E5E4    0xC   Name:                          0x2FEC4
# 0x2E5E8    0x10  FirstThunk:                    0x281E0
#
# api-ms-win-crt-runtime-l1-1-0.dll._initterm Hint[54]
# api-ms-win-crt-runtime-l1-1-0.dll._initterm_e Hint[55]
# api-ms-win-crt-runtime-l1-1-0.dll._c_exit Hint[21]
# api-ms-win-crt-runtime-l1-1-0.dll._register_thread_local_exe_atexit_callback Hint[61]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E5EC    0x0   OriginalFirstThunk:            0x2EF70
# 0x2E5EC    0x0   Characteristics:               0x2EF70
# 0x2E5F0    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E5F4    0x8   ForwarderChain:                0x0
# 0x2E5F8    0xC   Name:                          0x301C2
# 0x2E5FC    0x10  FirstThunk:                    0x280A8
#
# api-ms-win-crt-private-l1-1-0.dll._o__beginthreadex Hint[143]
# api-ms-win-crt-private-l1-1-0.dll._o__callnewh Hint[145]
# api-ms-win-crt-private-l1-1-0.dll._o__cexit Hint[147]
# api-ms-win-crt-private-l1-1-0.dll._o__configthreadlocale Hint[159]
# api-ms-win-crt-private-l1-1-0.dll._o__configure_wide_argv Hint[161]
# api-ms-win-crt-private-l1-1-0.dll._o__crt_atexit Hint[167]
# api-ms-win-crt-private-l1-1-0.dll._o__errno Hint[192]
# api-ms-win-crt-private-l1-1-0.dll._o__exit Hint[199]
# api-ms-win-crt-private-l1-1-0.dll._o__get_wide_winmain_command_line Hint[281]
# api-ms-win-crt-private-l1-1-0.dll._o__initialize_onexit_table Hint[317]
# api-ms-win-crt-private-l1-1-0.dll._o__initialize_wide_environment Hint[318]
# api-ms-win-crt-private-l1-1-0.dll._o__invalid_parameter_noinfo Hint[319]
# api-ms-win-crt-private-l1-1-0.dll._o__purecall Hint[579]
# api-ms-win-crt-private-l1-1-0.dll._o__register_onexit_function Hint[593]
# api-ms-win-crt-private-l1-1-0.dll._o__seh_filter_exe Hint[602]
# api-ms-win-crt-private-l1-1-0.dll._o__set_app_type Hint[604]
# api-ms-win-crt-private-l1-1-0.dll._o__set_fmode Hint[607]
# api-ms-win-crt-private-l1-1-0.dll._o__set_new_mode Hint[610]
# api-ms-win-crt-private-l1-1-0.dll._o__wcsicmp Hint[717]
# api-ms-win-crt-private-l1-1-0.dll._o__wtol Hint[823]
# api-ms-win-crt-private-l1-1-0.dll._o_exit Hint[877]
# api-ms-win-crt-private-l1-1-0.dll._o_free Hint[909]
# api-ms-win-crt-private-l1-1-0.dll._o_iswdigit Hint[945]
# api-ms-win-crt-private-l1-1-0.dll._o_malloc Hint[984]
# api-ms-win-crt-private-l1-1-0.dll._o_terminate Hint[1078]
# api-ms-win-crt-private-l1-1-0.dll.__CxxFrameHandler3 Hint[18]
# api-ms-win-crt-private-l1-1-0.dll.__current_exception Hint[32]
# api-ms-win-crt-private-l1-1-0.dll.__current_exception_context Hint[33]
# api-ms-win-crt-private-l1-1-0.dll._CxxThrowException Hint[1]
# api-ms-win-crt-private-l1-1-0.dll._o___stdio_common_vswprintf Hint[112]
# api-ms-win-crt-private-l1-1-0.dll.wcschr Hint[1131]
# api-ms-win-crt-private-l1-1-0.dll.__C_specific_handler Hint[12]
# api-ms-win-crt-private-l1-1-0.dll._o___std_exception_destroy Hint[95]
# api-ms-win-crt-private-l1-1-0.dll._o___std_exception_copy Hint[94]
# api-ms-win-crt-private-l1-1-0.dll._o___p__commode Hint[83]
# api-ms-win-crt-private-l1-1-0.dll.memcmp Hint[1122]
# api-ms-win-crt-private-l1-1-0.dll.memcpy Hint[1123]
# api-ms-win-crt-private-l1-1-0.dll.memmove Hint[1124]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E600    0x0   OriginalFirstThunk:            0x2EDF8
# 0x2E600    0x0   Characteristics:               0x2EDF8
# 0x2E604    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E608    0x8   ForwarderChain:                0x0
# 0x2E60C    0xC   Name:                          0x304F2
# 0x2E610    0x10  FirstThunk:                    0x27F30
#
# api-ms-win-core-com-l1-1-0.dll.CoTaskMemAlloc Hint[66]
# api-ms-win-core-com-l1-1-0.dll.CoWaitForMultipleHandles Hint[73]
# api-ms-win-core-com-l1-1-0.dll.CoCreateFreeThreadedMarshaler Hint[7]
# api-ms-win-core-com-l1-1-0.dll.CoCreateInstance Hint[9]
# api-ms-win-core-com-l1-1-0.dll.CoInitializeEx Hint[40]
# api-ms-win-core-com-l1-1-0.dll.CoUninitialize Hint[70]
# api-ms-win-core-com-l1-1-0.dll.CoCreateGuid Hint[8]
# api-ms-win-core-com-l1-1-0.dll.CoTaskMemFree Hint[67]
# api-ms-win-core-com-l1-1-0.dll.PropVariantClear Hint[80]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E614    0x0   OriginalFirstThunk:            0x2EED8
# 0x2E614    0x0   Characteristics:               0x2EED8
# 0x2E618    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E61C    0x8   ForwarderChain:                0x0
# 0x2E620    0xC   Name:                          0x30512
# 0x2E624    0x10  FirstThunk:                    0x28010
#
# api-ms-win-core-shlwapi-legacy-l1-1-0.dll.PathIsFileSpecW Hint[34]
# api-ms-win-core-shlwapi-legacy-l1-1-0.dll.PathFindExtensionW Hint[22]
# api-ms-win-core-shlwapi-legacy-l1-1-0.dll.PathFileExistsW Hint[20]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E628    0x0   OriginalFirstThunk:            0x2EF48
# 0x2E628    0x0   Characteristics:               0x2EF48
# 0x2E62C    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E630    0x8   ForwarderChain:                0x0
# 0x2E634    0xC   Name:                          0x3053C
# 0x2E638    0x10  FirstThunk:                    0x28080
#
# api-ms-win-core-winrt-string-l1-1-0.dll.WindowsCreateString Hint[10]
# api-ms-win-core-winrt-string-l1-1-0.dll.WindowsDeleteString Hint[12]
# api-ms-win-core-winrt-string-l1-1-0.dll.WindowsCreateStringReference Hint[11]
# api-ms-win-core-winrt-string-l1-1-0.dll.WindowsGetStringRawBuffer Hint[16]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E63C    0x0   OriginalFirstThunk:            0x2EF38
# 0x2E63C    0x0   Characteristics:               0x2EF38
# 0x2E640    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E644    0x8   ForwarderChain:                0x0
# 0x2E648    0xC   Name:                          0x30564
# 0x2E64C    0x10  FirstThunk:                    0x28070
#
# api-ms-win-core-winrt-l1-1-0.dll.RoGetActivationFactory Hint[1]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E650    0x0   OriginalFirstThunk:            0x2F0F0
# 0x2E650    0x0   Characteristics:               0x2F0F0
# 0x2E654    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E658    0x8   ForwarderChain:                0x0
# 0x2E65C    0xC   Name:                          0x30586
# 0x2E660    0x10  FirstThunk:                    0x28228
#
# api-ms-win-shcore-obsolete-l1-1-0.dll.SHStrDupW Hint[2]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E664    0x0   OriginalFirstThunk:            0x2F100
# 0x2E664    0x0   Characteristics:               0x2F100
# 0x2E668    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E66C    0x8   ForwarderChain:                0x0
# 0x2E670    0xC   Name:                          0x305AC
# 0x2E674    0x10  FirstThunk:                    0x28238
#
# api-ms-win-shcore-path-l1-1-0.dll Ordinal[170] (Imported by Ordinal)
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E678    0x0   OriginalFirstThunk:            0x2F110
# 0x2E678    0x0   Characteristics:               0x2F110
# 0x2E67C    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E680    0x8   ForwarderChain:                0x0
# 0x2E684    0xC   Name:                          0x305CE
# 0x2E688    0x10  FirstThunk:                    0x28248
#
# api-ms-win-shcore-scaling-l1-1-1.dll.GetDpiForMonitor Hint[0]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E68C    0x0   OriginalFirstThunk:            0x2EEB8
# 0x2E68C    0x0   Characteristics:               0x2EEB8
# 0x2E690    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E694    0x8   ForwarderChain:                0x0
# 0x2E698    0xC   Name:                          0x305F4
# 0x2E69C    0x10  FirstThunk:                    0x27FF0
#
# api-ms-win-core-rtlsupport-l1-1-0.dll.RtlCaptureContext Hint[766]
# api-ms-win-core-rtlsupport-l1-1-0.dll.RtlLookupFunctionEntry Hint[1278]
# api-ms-win-core-rtlsupport-l1-1-0.dll.RtlVirtualUnwind Hint[1602]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E6A0    0x0   OriginalFirstThunk:            0x2EE48
# 0x2E6A0    0x0   Characteristics:               0x2EE48
# 0x2E6A4    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E6A8    0x8   ForwarderChain:                0x0
# 0x2E6AC    0xC   Name:                          0x3061A
# 0x2E6B0    0x10  FirstThunk:                    0x27F80
#
# api-ms-win-core-errorhandling-l1-1-0.dll.UnhandledExceptionFilter Hint[17]
# api-ms-win-core-errorhandling-l1-1-0.dll.SetUnhandledExceptionFilter Hint[15]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E6B4    0x0   OriginalFirstThunk:            0x2EE80
# 0x2E6B4    0x0   Characteristics:               0x2EE80
# 0x2E6B8    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E6BC    0x8   ForwarderChain:                0x0
# 0x2E6C0    0xC   Name:                          0x30644
# 0x2E6C4    0x10  FirstThunk:                    0x27FB8
#
# api-ms-win-core-processthreads-l1-1-0.dll.TerminateProcess Hint[85]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E6C8    0x0   OriginalFirstThunk:            0x2EE90
# 0x2E6C8    0x0   Characteristics:               0x2EE90
# 0x2E6CC    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E6D0    0x8   ForwarderChain:                0x0
# 0x2E6D4    0xC   Name:                          0x3066E
# 0x2E6D8    0x10  FirstThunk:                    0x27FC8
#
# api-ms-win-core-processthreads-l1-1-1.dll.GetProcessMitigationPolicy Hint[29]
# api-ms-win-core-processthreads-l1-1-1.dll.IsProcessorFeaturePresent Hint[50]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E6DC    0x0   OriginalFirstThunk:            0x2EEA8
# 0x2E6DC    0x0   Characteristics:               0x2EEA8
# 0x2E6E0    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E6E4    0x8   ForwarderChain:                0x0
# 0x2E6E8    0xC   Name:                          0x30698
# 0x2E6EC    0x10  FirstThunk:                    0x27FE0
#
# api-ms-win-core-profile-l1-1-0.dll.QueryPerformanceCounter Hint[0]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E6F0    0x0   OriginalFirstThunk:            0x2EF08
# 0x2E6F0    0x0   Characteristics:               0x2EF08
# 0x2E6F4    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E6F8    0x8   ForwarderChain:                0x0
# 0x2E6FC    0xC   Name:                          0x306BC
# 0x2E700    0x10  FirstThunk:                    0x28040
#
# api-ms-win-core-sysinfo-l1-1-0.dll.GetSystemTimeAsFileTime Hint[22]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E704    0x0   OriginalFirstThunk:            0x2EE60
# 0x2E704    0x0   Characteristics:               0x2EE60
# 0x2E708    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E70C    0x8   ForwarderChain:                0x0
# 0x2E710    0xC   Name:                          0x306E0
# 0x2E714    0x10  FirstThunk:                    0x27F98
#
# api-ms-win-core-interlocked-l1-1-0.dll.InitializeSListHead Hint[0]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E718    0x0   OriginalFirstThunk:            0x2EE70
# 0x2E718    0x0   Characteristics:               0x2EE70
# 0x2E71C    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E720    0x8   ForwarderChain:                0x0
# 0x2E724    0xC   Name:                          0x30708
# 0x2E728    0x10  FirstThunk:                    0x27FA8
#
# api-ms-win-core-libraryloader-l1-2-0.dll.FreeLibrary Hint[13]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E72C    0x0   OriginalFirstThunk:            0x2EF18
# 0x2E72C    0x0   Characteristics:               0x2EF18
# 0x2E730    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x2E734    0x8   ForwarderChain:                0x0
# 0x2E738    0xC   Name:                          0x30732
# 0x2E73C    0x10  FirstThunk:                    0x28050
#
# api-ms-win-core-winrt-error-l1-1-0.dll.SetRestrictedErrorInfo Hint[18]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x2E740    0x0   OriginalFirstThunk:            0x2EEF8
# 0x2E740    0x0   Characteristics:               0x2EEF8
# ...
#             0x35658    0x0   OffsetToData:                  0x54CE8
#             0x3565C    0x4   Size:                          0x30
#             0x35660    0x8   CodePage:                      0x0
#             0x35664    0xC   Reserved:                      0x0
#
#   Id: [0x10] (RT_VERSION)
#   [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#   0x35038    0x0   Name:                          0x10
#   0x3503C    0x4   OffsetToData:                  0x80000180
#     [IMAGE_RESOURCE_DIRECTORY]
#     0x35180    0x0   Characteristics:               0x0
#     0x35184    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#     0x35188    0x8   MajorVersion:                  0x0
#     0x3518A    0xA   MinorVersion:                  0x0
#     0x3518C    0xC   NumberOfNamedEntries:          0x0
#     0x3518E    0xE   NumberOfIdEntries:             0x1
#       Id: [0x1]
#       [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#       0x35190    0x0   Name:                          0x1
#       0x35194    0x4   OffsetToData:                  0x80000468
#         [IMAGE_RESOURCE_DIRECTORY]
#         0x35468    0x0   Characteristics:               0x0
#         0x3546C    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#         0x35470    0x8   MajorVersion:                  0x0
#         0x35472    0xA   MinorVersion:                  0x0
#         0x35474    0xC   NumberOfNamedEntries:          0x0
#         0x35476    0xE   NumberOfIdEntries:             0x1
#         \--- LANG [9,1][LANG_ENGLISH,SUBLANG_ENGLISH_US]
#           [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#           0x35478    0x0   Name:                          0x409
#           0x3547C    0x4   OffsetToData:                  0x668
#             [IMAGE_RESOURCE_DATA_ENTRY]
#             0x35668    0x0   OffsetToData:                  0x54D18
#             0x3566C    0x4   Size:                          0x374
#             0x35670    0x8   CodePage:                      0x0
#             0x35674    0xC   Reserved:                      0x0
#
#   Id: [0x18] (RT_MANIFEST)
#   [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#   0x35040    0x0   Name:                          0x18
#   0x35044    0x4   OffsetToData:                  0x80000198
#     [IMAGE_RESOURCE_DIRECTORY]
#     0x35198    0x0   Characteristics:               0x0
#     0x3519C    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#     0x351A0    0x8   MajorVersion:                  0x0
#     0x351A2    0xA   MinorVersion:                  0x0
#     0x351A4    0xC   NumberOfNamedEntries:          0x0
#     0x351A6    0xE   NumberOfIdEntries:             0x1
#       Id: [0x1]
#       [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#       0x351A8    0x0   Name:                          0x1
#       0x351AC    0x4   OffsetToData:                  0x80000480
#         [IMAGE_RESOURCE_DIRECTORY]
#         0x35480    0x0   Characteristics:               0x0
#         0x35484    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#         0x35488    0x8   MajorVersion:                  0x0
#         0x3548A    0xA   MinorVersion:                  0x0
#         0x3548C    0xC   NumberOfNamedEntries:          0x0
#         0x3548E    0xE   NumberOfIdEntries:             0x1
#         \--- LANG [9,1][LANG_ENGLISH,SUBLANG_ENGLISH_US]
#           [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#           0x35490    0x0   Name:                          0x409
#           0x35494    0x4   OffsetToData:                  0x678
#             [IMAGE_RESOURCE_DATA_ENTRY]
#             0x35678    0x0   OffsetToData:                  0x37770
#             0x3567C    0x4   Size:                          0x4E4
#             0x35680    0x8   CodePage:                      0x0
#             0x35684    0xC   Reserved:                      0x0
#
#
# ----------LOAD_CONFIG----------
#
# [IMAGE_LOAD_CONFIG_DIRECTORY]
# 0x27790    0x0   Size:                          0x138
# 0x27794    0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x27798    0x8   MajorVersion:                  0x0
# 0x2779A    0xA   MinorVersion:                  0x0
# 0x2779C    0xC   GlobalFlagsClear:              0x0
# 0x277A0    0x10  GlobalFlagsSet:                0x0
# 0x277A4    0x14  CriticalSectionDefaultTimeout: 0x0
# 0x277A8    0x18  DeCommitFreeBlockThreshold:    0x0
# 0x277B0    0x20  DeCommitTotalFreeThreshold:    0x0
# 0x277B8    0x28  LockPrefixTable:               0x0
# 0x277C0    0x30  MaximumAllocationSize:         0x0
# 0x277C8    0x38  VirtualMemoryThreshold:        0x0
# 0x277D0    0x40  ProcessAffinityMask:           0x0
# 0x277D8    0x48  ProcessHeapFlags:              0x0
# 0x277DC    0x4C  CSDVersion:                    0x0
# 0x277DE    0x4E  Reserved1:                     0x0
# 0x277E0    0x50  EditList:                      0x0
# 0x277E8    0x58  SecurityCookie:                0x1400313F0
# 0x277F0    0x60  SEHandlerTable:                0x0
# 0x277F8    0x68  SEHandlerCount:                0x0
# 0x27800    0x70  GuardCFCheckFunctionPointer:   0x140028258
# 0x27808    0x78  Reserved2:                     0x140028268
# 0x27810    0x80  GuardCFFunctionTable:          0x140028374
# 0x27818    0x88  GuardCFFunctionCount:          0xB0
# 0x27820    0x90  GuardFlags:                    0x10C17500
#
# ----------Debug information----------
#
# [IMAGE_DEBUG_DIRECTORY]
# 0x2C160    0x0   Characteristics:               0x0
# 0x2C164    0x4   TimeDateStamp:                 0xF59533D5 [Sun Jul 25 10:54:13 2100 UTC]
# 0x2C168    0x8   MajorVersion:                  0x0
# 0x2C16A    0xA   MinorVersion:                  0x0
# 0x2C16C    0xC   Type:                          0x2
# 0x2C170    0x10  SizeOfData:                    0x24
# 0x2C174    0x14  AddressOfRawData:              0x2C988
# 0x2C178    0x18  PointerToRawData:              0x2C988
# Type: IMAGE_DEBUG_TYPE_CODEVIEW
#
#     [CV_INFO_PDB70]
#     0x2C988    0x0   CvSignature:                   0x53445352
#     0x2C98C    0x4   Signature_Data1:               E00A25CF
#     0x2C990    0x8   Signature_Data2:               2AC7
#     0x2C992    0xA   Signature_Data3:               95B7
#     0x2C994    0xC   Signature_Data4:               6BB88EAB3656BFA9
#     0x2C99C    0x14  Age:                           0x1
#     0x2C9A0    0x18  PdbFileName:                   notepad.pdb
#
# [IMAGE_DEBUG_DIRECTORY]
# 0x2C17C    0x0   Characteristics:               0x0
# 0x2C180    0x4   TimeDateStamp:                 0xF59533D5 [Sun Jul 25 10:54:13 2100 UTC]
# 0x2C184    0x8   MajorVersion:                  0x0
# 0x2C186    0xA   MinorVersion:                  0x0
# 0x2C188    0xC   Type:                          0xD
# 0x2C18C    0x10  SizeOfData:                    0x454
# 0x2C190    0x14  AddressOfRawData:              0x2C9AC
# 0x2C194    0x18  PointerToRawData:              0x2C9AC
# Type: IMAGE_DEBUG_TYPE_POGO
#
# [IMAGE_DEBUG_DIRECTORY]
# 0x2C198    0x0   Characteristics:               0x0
# 0x2C19C    0x4   TimeDateStamp:                 0xF59533D5 [Sun Jul 25 10:54:13 2100 UTC]
# 0x2C1A0    0x8   MajorVersion:                  0x0
# 0x2C1A2    0xA   MinorVersion:                  0x0
# 0x2C1A4    0xC   Type:                          0x10
# 0x2C1A8    0x10  SizeOfData:                    0x24
# 0x2C1AC    0x14  AddressOfRawData:              0x2CE00
# 0x2C1B0    0x18  PointerToRawData:              0x2CE00
# Type: 0x10(Unknown)
#
# ----------Base relocations----------
#
# [IMAGE_BASE_RELOCATION]
# 0x54000    0x0   VirtualAddress:                0x27000
# 0x54004    0x4   SizeOfBlock:                   0x1FC
#     00027000h DIR64
#     00027008h DIR64
#     00027010h DIR64
#     00027018h DIR64
#     00027020h DIR64
#     00027028h DIR64
#     00027030h DIR64
#     00027038h DIR64
#     00027040h DIR64
#     00027048h DIR64
#     00027050h DIR64
#     00027058h DIR64
#     00027060h DIR64
#     00027068h DIR64
#     00027070h DIR64
#     00027078h DIR64
#     00027080h DIR64
#     00027088h DIR64
#     00027090h DIR64
#     00027098h DIR64
#     000270A0h DIR64
#     000270A8h DIR64
#     000270B0h DIR64
#     000270B8h DIR64
#     000270C0h DIR64
#     000270C8h DIR64
#     000270D0h DIR64
#     000270D8h DIR64
#     000270E0h DIR64
#     000270E8h DIR64
#     000270F0h DIR64
#     000270F8h DIR64
#     00027100h DIR64
#     00027108h DIR64
#     00027110h DIR64
#     00027118h DIR64
#     00027120h DIR64
#     00027128h DIR64
#     00027130h DIR64
#     00027138h DIR64
#     00027140h DIR64
#     00027148h DIR64
#     00027150h DIR64
#     00027158h DIR64
#     00027160h DIR64
#     00027168h DIR64
#     00027170h DIR64
#     00027178h DIR64
#     00027180h DIR64
#     00027188h DIR64
#     00027190h DIR64
#     00027198h DIR64
#     000271A0h DIR64
#     000271A8h DIR64
#     000271B0h DIR64
#     000271B8h DIR64
#     000271C0h DIR64
#     000271C8h DIR64
#     000271D0h DIR64
#     000271D8h DIR64
#     000271E0h DIR64
#     000271E8h DIR64
#     000271F0h DIR64
#     000271F8h DIR64
#     00027200h DIR64
#     00027208h DIR64
#     00027210h DIR64
#     00027218h DIR64
#     00027220h DIR64
#     00027228h DIR64
#     00027230h DIR64
#     00027238h DIR64
#     00027240h DIR64
#     00027248h DIR64
#     00027250h DIR64
#     00027258h DIR64
#     00027260h DIR64
#     00027268h DIR64
#     00027270h DIR64
#     00027278h DIR64
#     00027280h DIR64
#     00027288h DIR64
#     00027290h DIR64
#     00027298h DIR64
#     000272A0h DIR64
#     000272A8h DIR64
#     000272B0h DIR64
#     000272B8h DIR64
#     000272C0h DIR64
#     000272C8h DIR64
#     000272D0h DIR64
#     000272D8h DIR64
#     000272E0h DIR64
#     000272E8h DIR64
#     000272F0h DIR64
#     000272F8h DIR64
#     00027300h DIR64
#     00027308h DIR64
#     00027310h DIR64
#     00027318h DIR64
#     00027320h DIR64
#     00027328h DIR64
#     00027338h DIR64
#     00027340h DIR64
#     00027348h DIR64
#     00027350h DIR64
#     00027358h DIR64
#     00027360h DIR64
#     00027368h DIR64
#     00027370h DIR64
#     00027378h DIR64
#     00027380h DIR64
#     00027388h DIR64
#     00027390h DIR64
#     00027398h DIR64
#     000273A0h DIR64
#     000273A8h DIR64
#     000273B0h DIR64
#     000273B8h DIR64
#     000273C0h DIR64
#     000273C8h DIR64
#     000273D0h DIR64
#     000273D8h DIR64
#     000273E0h DIR64
#     000273E8h DIR64
#     000273F0h DIR64
#     000273F8h DIR64
#     00027400h DIR64
#     00027408h DIR64
#     00027410h DIR64
#     00027418h DIR64
#     00027420h DIR64
#     00027428h DIR64
#     00027430h DIR64
#     00027438h DIR64
#     00027440h DIR64
#     00027448h DIR64
#     00027450h DIR64
#     00027458h DIR64
#     00027460h DIR64
#     00027468h DIR64
#     00027470h DIR64
#     00027478h DIR64
#     00027480h DIR64
#     00027488h DIR64
#     00027490h DIR64
#     00027498h DIR64
#     000274A0h DIR64
#     000274A8h DIR64
#     000274B0h DIR64
#     000274B8h DIR64
#     000274C0h DIR64
#     000274C8h DIR64
#     000274D0h DIR64
#     000274D8h DIR64
#     000274E0h DIR64
#     000274E8h DIR64
#     000274F0h DIR64
#     000274F8h DIR64
#     00027500h DIR64
#     00027508h DIR64
#     00027510h DIR64
#     00027518h DIR64
#     00027520h DIR64
#     00027528h DIR64
#     00027530h DIR64
#     00027538h DIR64
#     00027540h DIR64
#     00027548h DIR64
#     00027550h DIR64
#     00027558h DIR64
#     00027560h DIR64
#     00027568h DIR64
#     00027570h DIR64
#     00027578h DIR64
#     00027580h DIR64
#     00027588h DIR64
#     00027590h DIR64
#     00027598h DIR64
#     000275A0h DIR64
#     000275B0h DIR64
#     000275B8h DIR64
#     000275C0h DIR64
#     000275C8h DIR64
#     000275D0h DIR64
#     000275D8h DIR64
#     000275E0h DIR64
#     000275E8h DIR64
#     000275F0h DIR64
#     000275F8h DIR64
#     00027600h DIR64
#     00027608h DIR64
#     00027610h DIR64
#     00027618h DIR64
#     00027620h DIR64
#     00027628h DIR64
#     00027630h DIR64
#     00027638h DIR64
#     00027640h DIR64
#     00027648h DIR64
#     00027650h DIR64
#     00027658h DIR64
#     00027660h DIR64
#     00027668h DIR64
#     00027670h DIR64
#     00027678h DIR64
#     00027680h DIR64
#     00027688h DIR64
#     00027690h DIR64
#     00027698h DIR64
#     000276A0h DIR64
#     000276A8h DIR64
#     000276B0h DIR64
#     000276B8h DIR64
#     000276C0h DIR64
#     000276C8h DIR64
#     000276D0h DIR64
#     000276D8h DIR64
#     000276E0h DIR64
#     000276E8h DIR64
#     000276F0h DIR64
#     000276F8h DIR64
#     00027700h DIR64
#     00027708h DIR64
#     00027710h DIR64
#     00027718h DIR64
#     00027720h DIR64
#     00027728h DIR64
#     00027730h DIR64
#     00027738h DIR64
#     00027740h DIR64
#     00027748h DIR64
#     00027750h DIR64
#     00027758h DIR64
#     00027760h DIR64
#     00027768h DIR64
#     00027770h DIR64
#     00027778h DIR64
#     00027780h DIR64
#     00027788h DIR64
#     000277E8h DIR64
#     00027800h DIR64
#     00027808h DIR64
#     00027810h DIR64
#     00027830h DIR64
#     00027898h DIR64
#     000278A8h DIR64
#     000278B0h DIR64
#     000278B8h DIR64
#     000278C0h DIR64
#
# [IMAGE_BASE_RELOCATION]
# 0x541FC    0x0   VirtualAddress:                0x28000
# 0x54200    0x4   SizeOfBlock:                   0x3C
#     00028258h DIR64
#     00028260h DIR64
#     00028268h DIR64
#     00028270h DIR64
#     00028278h DIR64
#     00028288h DIR64
#     00028290h DIR64
#     00028298h DIR64
#     000282A0h DIR64
#     000282A8h DIR64
#     000282B0h DIR64
#     000282B8h DIR64
#     000282C0h DIR64
#     000282C8h DIR64
#     000282D0h DIR64
#     000282D8h DIR64
#     000282E0h DIR64
#     000282E8h DIR64
#     000282F0h DIR64
#     000282F8h DIR64
#     00028300h DIR64
#     00028318h DIR64
#     00028320h DIR64
#     00028328h DIR64
#     00028330h DIR64
#     00028000h ABSOLUTE
#
# [IMAGE_BASE_RELOCATION]
# 0x54238    0x0   VirtualAddress:                0x31000
# 0x5423C    0x4   SizeOfBlock:                   0x84
#     00031000h DIR64
#     00031008h DIR64
#     00031010h DIR64
#     00031018h DIR64
#     00031020h DIR64
#     00031028h DIR64
#     00031030h DIR64
#     00031038h DIR64
#     00031040h DIR64
#     00031048h DIR64
#     00031050h DIR64
#     00031058h DIR64
#     00031060h DIR64
#     00031068h DIR64
#     00031070h DIR64
#     00031078h DIR64
#     00031080h DIR64
#     00031088h DIR64
#     00031090h DIR64
#     00031098h DIR64
#     000310A0h DIR64
#     000310A8h DIR64
#     000310B0h DIR64
#     000310B8h DIR64
#     000310C0h DIR64
#     000310C8h DIR64
#     000310D8h DIR64
#     000310E0h DIR64
#     000310E8h DIR64
#     000310F0h DIR64
#     000310F8h DIR64
#     00031100h DIR64
#     00031108h DIR64
#     00031110h DIR64
#     00031118h DIR64
#     00031120h DIR64
#     00031128h DIR64
#     00031130h DIR64
#     00031138h DIR64
#     00031140h DIR64
#     00031148h DIR64
#     00031150h DIR64
#     00031158h DIR64
#     00031160h DIR64
#     00031168h DIR64
#     00031178h DIR64
#     00031188h DIR64
#     00031198h DIR64
#     000311A8h DIR64
#     000311B8h DIR64
#     000311C8h DIR64
#     000311D8h DIR64
#     000311E8h DIR64
#     000311F0h DIR64
#     00031200h DIR64
#     00031230h DIR64
#     00031248h DIR64
#     00031348h DIR64
#     00031370h DIR64
#     00031398h DIR64
#     000313C8h DIR64
#     00031000h ABSOLUTE
#
# [IMAGE_BASE_RELOCATION]
# 0x542BC    0x0   VirtualAddress:                0x36000
# 0x542C0    0x4   SizeOfBlock:                   0x60
#     00036000h DIR64
#     00036008h DIR64
#     00036010h DIR64
#     00036018h DIR64
#     00036020h DIR64
#     00036028h DIR64
#     00036030h DIR64
#     00036038h DIR64
#     00036040h DIR64
#     00036048h DIR64
#     00036050h DIR64
#     00036058h DIR64
#     00036060h DIR64
#     00036068h DIR64
#     00036070h DIR64
#     00036078h DIR64
#     00036080h DIR64
#     00036088h DIR64
#     00036090h DIR64
#     00036098h DIR64
#     000360A8h DIR64
#     000360B0h DIR64
#     000360B8h DIR64
#     000360C0h DIR64
#     000360C8h DIR64
#     000360D0h DIR64
#     000360D8h DIR64
#     000360E0h DIR64
#     000360E8h DIR64
#     000360F8h DIR64
#     00036100h DIR64
#     00036110h DIR64
#     00036118h DIR64
#     00036120h DIR64
#     00036128h DIR64
#     00036130h DIR64
#     00036138h DIR64
#     00036140h DIR64
#     00036148h DIR64
#     00036158h DIR64
#     00036160h DIR64
#     00036168h DIR64
#     00036178h DIR64
#     00036000h ABSOLUTE

# %%
'''PE 헤더 특성화'''
import pefile
from os import listdir
from os.path import isfile, join

directories = ["Benign PE Samples", "Malicious PE Samples"]

# 파일 섹션 이름을 수집하고 함수와 가독성과 정규화를 위해 섹션 이름을 전처리하는 함수를 정의
def get_section_names(pe):
    # PE 파일에서 섹션의 이름 리스트를 만든다
    list_of_section_names = []
    for sec in pe.sections:
        normalized_name = sec.Name.decode().replace("\x00","").lower()
        list_of_section_names.append(normalized_name)
    return list_of_section_names

# import 항목을 전처리한 후 이름을 소문자로 표준화하는 함수를 정의한다.
def preprocess_imports(list_of_DLLs):
    # PE파일에서 Import 항목의 이름을 소문자로 정규화한다.
    return [x.decode().split(".")[0].lower() for x in list_of_DLLs]

# pefile을 사용해 파일에서 import 항목을 수집하븐ㄴ 함수를 정의한다.
def get_imports(pe):
    # PE 파일에서 Import 항목들의 리스트를 만든다.
    list_of_imports = []
    for entry in pe.DIRECTORY_ENTRY_IMPORT:
        list_of_imports.appned(entry.dll)
    return preprocess_imports(list_of_imports)

# 마지막으로 모든 파일에 대해 반복하고 특성을 저장할 리스트를 만든다.
imports_corpus = []
num_sections = []
section_names = []

for dataset_path in directories:
    samples = [f for f in listdir(dataset_path) if isfile(join(dataset_path, f))]
    for file in samples:
        file_path = dataset_path + "/" + file
        try:
            # 위의 특성을 수집하는 것 이외에 파일의 섹션 갯수도 수집한다.
            pe = pefile.PE(file_path)
            imports = get_imports(pe)
            n_sections = len(pe.sections)
            sec_names = get_section_names(pe)
            imports_corpus.append(imports)
            num_sections.append(n_sections)
            section_names.append(sec_names)
        except Exception as e:
            print(e)
            print(f"{file_path}의 헤더를 구분 분석할 수 없습니다.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13864/1703298518.py in <module>
#      34
#      35 for dataset_path in directories:
# ---> 36     samples = [f for f in listdir(dataset_path) if isfile(join(dataset_path, f))]
#      37     for file in samples:
#      38         file_path = dataset_path + "/" + file
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'Benign PE Samples'
