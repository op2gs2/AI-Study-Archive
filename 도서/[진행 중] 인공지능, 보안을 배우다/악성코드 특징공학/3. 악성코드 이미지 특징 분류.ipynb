# %%
import numpy as np
import os, array
import imageio # scipy.misc 대신 사용
import glob
from PIL import Image


class IMAGE_feature():

    def __init__(self, in_path, out_path):

        self.in_path = in_path
        self.out_path = out_path

    # 
    def get_image(self, path, file):
            # 프로그램이 존재하는 경로를 지정
            filename = path + file
            
            # 이미지화 할 프로그램을 불러들임
            f = open(filename,'rb')
            ln = os.path.getsize(filename) # 프로그램의 크기
            
            # 
            width = int(ln**0.5) # 파일 길이의 제곱근을 구함(정사각형 모양 이미지 구현을 위해)
            rem = ln % width 
            
            a = array.array("B") # uint8 배열을 선언
            a.fromfile(f,ln-rem) # 파일 객체의 내용을 지정된 수만큼 읽어들임 (파일의 바이너리로 배열을 구성)
            f.close() 

            g = np.reshape(a, (int(len(a)/width), width)) # 배열의 모양을 정사각형으로 재조정
            g = np.uint8(g) #g np배열을 uint8형으로 형변환
            
            # 이미지가 저장될 경로를 지정
            fpng = self.out_path + file + ".png"
            imageio.imwrite(fpng, g) # [수정사항] scipy.misc.imsave(fpng, g) 대신 사용

            outfile = self.out_path + file + "_thumb.png"
            print(outfile)
            size = 256, 256

            if fpng != outfile:
                im = Image.open(fpng)
                im.thumbnail(size, Image.ANTIALIAS) # 이미지를 256x256 크기의 썸네일로 생성
                im.save(outfile, "PNG")

    def get_all(self):
        path = self.in_path

        for file in os.listdir(path): 
            self.get_image(path, file)



def main():

    mal_path = '/mal/'
    nor_path = '/mal/'

    mal_out_path = './'
    nor_out_path = './'

    im1 = IMAGE_feature(mal_path, mal_out_path)
    im1.get_all()

    im2 = IMAGE_feature(nor_path, nor_out_path)
    im2.get_all()


if __name__ == '__main__':
    main()
# Out:
# ./c522418670b4efa6c754ea19bf18e60d31e8c17929038cd3f14317134230a6e6_thumb.png
# ./4e87a0794bf73d06ac1ce4a37e33eb832ff4c89fb9e4266490c7cef9229d27a7_thumb.png
# ./37ea273266aa2d28430194fca27849170d609d338abc9c6c43c4e6be1bcf51f9_thumb.png
# ./45a4bd970485ca539c95d746fbe8866f868972dcf7f1d196199ed7ea8b50be5b_thumb.png
# ./358a5079b824548ef87fcf89d3e4b5284e780edc4de8a450f3e51878d1290eca_thumb.png
# ./7682b842ed75b69e23c5deecf05a45ee79c723d98cfb6746380d748145bfc1af_thumb.png
# ./a50f1be63ef1f51feac8f36a1b03664c4b6e8914633f6d71c5c7007984caf93c_thumb.png
# ./2573b356452dd5ee24c10537fa4848d882fa40a2a8fa5a181624ba460e1f769a_thumb.png
# ./e796e64c5f9a7568773bd2924e992172f222957e039ab7b41ade44865d0a48e5_thumb.png
# ./b4d73b07aa627674b03f9c96dd5883dcd78b73e5baba6426dcc87ff0e771b265_thumb.png
# ./91bfa2445d998425c81f30d293235429ca6a8c6c8f326536478952a2a6754aac_thumb.png
# ./3329641a171508fa6b1ad7674b31431093d46be190d1a51acd77e486f42d9c8e_thumb.png
# ./775c7bd9e820c4dfd0fabdfeade2de901414bd46d2691ea5020a818f6a42eb83_thumb.png
# ./6f9fcfaa7d942dea200107857c51c4fbcd7ac5922f090a1b9dc91e0e67e03fa3_thumb.png
# ./b9079fb0fff9f40d7b5544f29d260b1659d8fcf019deadc72ec2c12882203a66_thumb.png
# ./c0242d686b4c1707f9db2eb5afdd306507ceb5637d72662dff56c439330dbdf1_thumb.png
# ./2f3409bb36d5411d1a02ebd189c305e2b20f744c204f15eef9be459ec398448b_thumb.png
# ./0032588b8d93a807cf0f48a806ccf125677503a6fabe4105a6dc69e81ace6091_thumb.png
# ./c140c8dc1453d7213da39a5020d6c90ef00d00491bb769cb762d6cc7c64372e7_thumb.png
